# %% [markdown]
# # Make Dataset
#
# Based on: https://huggingface.co/docs/transformers/tasks/translation

# %%
import sys, os, datetime
import json
import torch
import random
import glob
from tqdm.notebook import tqdm
# from transformers import AutoTokenizer
# from transformers import DataCollatorForSeq2Seq
# from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer
# from transformers import TranslationPipeline
from datasets import load_dataset, Dataset
import cdli
import languages

# %%
os.environ["TOKENIZERS_PARALLELISM"] = "false"

source_langs = set(["akk", "sux"])

# target_langs = set(["en", "it", "es", "fr", "de"])
target_langs = set(["en"])


model_max_length = 512

paragraphs = True

test_publication_ids = set(["P393923"])

output_path = "../data/dataset_index.json"

# %% [markdown]
# ## Load All Publications

# %%
publications = cdli.get_atf()
# Out:
# Downloading https://github.com/cdli-gh/data/raw/master/cdliatf_unblocked.atf
# Parsing atf

# %%
len(publications), "publications"
# Out:
# (134712, 'publications')

# %% [markdown]
# ## Find those with translations

# %%
def target_ok(target_text):
    if len(target_text) == 0:
        return False
    if len(set(target_text.replace(" ", ""))) < 2:
        return False
    return True
    

def test_target_ok(text):
    ok = target_ok(text)
    print(ok, repr(text))
    
test_target_ok("")
test_target_ok(" ")
test_target_ok("xx xxx x")
test_target_ok(".. . .. ")
test_target_ok("Hi")
# Out:
# False ''
# False ' '
# False 'xx xxx x'
# False '.. . .. '
# True 'Hi'

# %%
def pub_has_text(pub):
    for a in pub.text_areas:
        for l in a.lines:
            if len(l.text) > 0 and "en" in l.languages and target_ok(l.languages["en"]):
                return True
    return False

# %%
akk_pubs = [x for x in publications if x.language == "akk" and pub_has_text(x)]
print(len(akk_pubs), "akk pubs")
# Out:
# 978 akk pubs

# %%
akk_pubs[0]
# Out:
# Publication('P464358', 'akk', [TextArea('object composite text', []), TextArea('surface a', []), TextArea('prologue', [TextLine('1.', 'i3-nu an s,i-ru-um', {'akkts': 'īnu anum ṣīrum', 'en': 'When the august Anu,'}), TextLine('2.', '_lugal_ {d}a-nun-na-ki', {'akkts': 'šar anunnakī', 'en': 'king of the Anunnaku,'}), TextLine('3.', '{d}en-lil2', {'akkts': 'enlil', 'en': 'and Enlil,'}), TextLine('4.', 'be-el sza-me-e', {'akkts': 'bēl šamê', 'en': 'lord of heaven'}), TextLine('5.', 'u3 er-s,e-tim', {'akkts': 'u erṣetim', 'en': 'and earth,'}), TextLine('6.', 'sza-i-im', {'akkts': 'šā’im', 'en': 'who determines'}), TextLine('7.', 'szi-ma-at _kalam_', {'akkts': 'šīmāt mātim', 'en': 'the destinies of the land,'}), TextLine('8.', 'a-na {d}marduk', {'akkts': 'ana marduk', 'en': 'to Marduk,'}), TextLine('9.', '_dumu_ re-esz-ti-im', {'akkts': 'mārim rēštîm', 'en': 'the firstborn son'}), TextLine('10.', 'sza {d}en-ki', {'akkts': 'ša ea', 'en': 'of Ea,'}), TextLine('11.', '{d}en-lil2-ut', {'akkts': 'illilūt', 'en': 'supreme power'}), TextLine('12.', 'kisz ni-szi3', {'akkts': 'kiššat nišī', 'en': 'over all peoples,'}), TextLine('13.', 'i-szi-mu-szum', {'akkts': 'išīmušum', 'en': 'allotted,'}), TextLine('14.', 'in i-gi4-gi4', {'akkts': 'in igigī', 'en': 'among the Igigu,'}), TextLine('15.', 'u2-szar-bi2-u3-szu', {'akkts': 'ušarbi’ušu', 'en': 'exalted him,'}), TextLine('16.', 'babila{ki}', {'akkts': 'bābilam', 'en': 'Babylon'}), TextLine('17.', 'szum-szu s,i-ra-am ib-bi-u3', {'akkts': 'šumšu ṣīram ibbi’u', 'en': 'with its august name named,'}), TextLine('18.', 'in ki-ib-ra-tim', {'akkts': 'in kibrātim', 'en': 'and within the regions'}), TextLine('19.', 'u2-sza-t,e4-ru-szu', {'akkts': 'ušāterušu', 'en': 'made it supreme;'}), TextLine('20.', 'i-na li-ib-bi-szu', {'akkts': 'ina libbišu', 'en': 'and within it'}), TextLine('21.', 'szar-ru-tam da-ri2-tam', {'akkts': 'šarrūtam dārītam', 'en': 'eternal kingship'}), TextLine('22.', 'sza ki-ma sza-me-e', {'akkts': 'ša kīma šamê', 'en': 'whose, like heaven'}), TextLine('23.', 'u3 er-s,e-tim', {'akkts': 'u erṣetim', 'en': 'and earth,'}), TextLine('24.', 'isz-da-sza', {'akkts': 'išdāša', 'en': 'foundations'}), TextLine('25.', 'szu-ur2-szu-da', {'akkts': 'šuršudā', 'en': 'are fixed,'}), TextLine('26.', 'u2-ki-in-nu-szum', {'akkts': 'ukinnušum', 'en': 'established for him;'}), TextLine('27.', 'i-nu-mi-szu', {'akkts': 'inūmišu', 'en': 'at that time,'}), TextLine('28.', '{disz}ha-am-mu-ra-pi2', {'akkts': 'ḫammurapi', 'en': 'Hammurapi'}), TextLine('29.', 'ru-ba-am', {'akkts': 'rubâm', 'en': 'the prince'}), TextLine('30.', "na-a'-dam", {'akkts': 'na’dam', 'en': 'pious,'}), TextLine('31.', 'pa-li-ih i3-li2 ia-ti', {'akkts': 'pāliḫ ilī yâti', 'en': 'who venerates the gods, me'}), TextLine('32.', 'mi-sza-ra-am', {'akkts': 'mīšaram', 'en': 'justice'}), TextLine('33.', 'i-na ma-tim', {'akkts': 'ina mātim', 'en': 'in the land,'}), TextLine('34.', 'a-na szu-pi2-i-im', {'akkts': 'ana šūpîm', 'en': 'to make prevail,'}), TextLine('35.', 'ra-ga-am u3 s,e-nam', {'akkts': 'raggam u ṣēnam', 'en': 'the wicked and the evil'}), TextLine('36.', 'a-na hu-ul-lu-qi2-im', {'akkts': 'ana ḫulluqim', 'en': 'to destroy,'}), TextLine('37.', 'dan-nu-um', {'akkts': 'dannum', 'en': 'that the strong'}), TextLine('38.', 'en-sza-am', {'akkts': 'enšam', 'en': 'the weak'}), TextLine('39.', 'a-na la ha-ba-li-im', {'akkts': 'ana la ḫabālim', 'en': 'not oppress,'}), TextLine('40.', 'ki-ma {d}utu', {'akkts': 'kīma šamaš', 'en': 'like Šamaš'}), TextLine('41.', 'a-na _sag-ge6_', {'akkts': 'ana ṣalmāt qaqqadim', 'en': 'to the black-headed ones'}), TextLine('42.', 'wa-s,e-e-em-ma', {'akkts': 'waṣêmma', 'en': 'to rise,'}), TextLine('43.', 'ma-tim', {'akkts': 'mātim', 'en': 'the land'}), TextLine('44.', 'nu-wu-ri-im', {'akkts': 'nuwwurim', 'en': 'to illuminate,'}), TextLine('45.', 'an', {'akkts': 'anum', 'en': 'Anu'}), TextLine('46.', 'u3 {d}en-lil2', {'akkts': 'u enlil', 'en': 'and Enlil'}), TextLine('47.', 'a-na szi-ir ni-szi', {'akkts': 'ana šīr nišī', ' ...

# %%
sux_pubs = [x for x in publications if x.language == "sux" and pub_has_text(x)]
print(len(sux_pubs), "sux pubs")
# Out:
# 4149 sux pubs

# %%
sux_pubs[0]
# Out:
# Publication('P010481', 'sux', [TextArea('tablet', []), TextArea('obverse', []), TextArea('column 1', [TextLine('1.', '2(u@c) 2(asz@c) uruda ma-na', {'en': '22 mana copper:'}), TextLine('2.', 'sa10 GAN2', {'en': '(this is) the price of the field;'}), TextLine('3.', '1(esze3@c) 2(iku@c) GAN2-bi', {'en': 'its surface (is) 8 iku;'}), TextLine('4.', '1(u@c) 6(asz@c) uruda ma-na', {'en': '16 mana copper:'}), TextLine('5.', 'nig2-diri', {'en': '(this is) the additional payment;'}), TextLine('6.', '2(asz@c) sze lid2-ga', {'en': '2 lidga-measures of barley:'}), TextLine('7.', 'nig2-ba', {'en': '(this is) the gift;'}), TextLine('8.', '1(asz@c) tug2 szu', {'en': '1 šu-garment,'})]), TextArea('column 2', [TextLine('1.', '1(asz@c) me-gal2 tug2', {'en': '1 megal-garment:'}), TextLine('2.', 'tug2', {'en': '(this is) the garment (payment);'}), TextLine('3.', '4(u@c) ninda', {'en': '40 breads,'}), TextLine('4.', '1(gesz2@c) gug2', {'en': '60 cakes,'}), TextLine('5.', '6(asz@c) kur2 tu7(|HIxASZ@c|)', {'en': '6 kur-measures of soup,'}), TextLine('6.', '6(asz@c) kur2 |GA2x(HA.A)|', {'en': '6 kur-measures of dried fish,'}), TextLine('7.', '1(asz@c) i3 sila3', {'en': '1 sila oil,'}), TextLine('8.', 'amar-abzu', {'en': '(to) Amar-abzu,'}), TextLine('9.', 'gan-utu', {'en': 'Gan-utu,'}), TextLine('10.', 'nin-nu-SZE3-SZE3', {'en': 'Nin-nu-še-še,'}), TextLine('11.', 'lugal-e2-ni-sze3', {'en': 'Lugal-e-ni-še:'})]), TextArea('column 3', [TextLine('1.', 'lu2 sa10 gu7', {'en': '(they are) the sellers;'}), TextLine('2.', '2(barig@c) sze', {'en': '2 barig-measures of barley,'}), TextLine('3.', '1(u@c) ninda', {'en': '10 breads,'}), TextLine('4.', '1(u@c) 6(asz@c) gug2', {'en': '16 cakes,'}), TextLine('5.', '2(asz@c) kur2 tu7', {'en': '2 kur-measures of soup,'}), TextLine('6.', '2(asz@c) kur2 |GA2x(HA.A)|', {'en': '2 kur-measures o) dried fish,'}), TextLine('7.', 'ur-e', {'en': '(to) Ur-e,'}), TextLine('8.', 'szesz lu2', {'en': ''}), TextLine('9.', '1(asz@c) ad-da-ki-za', {'en': '1 Ad-da-ki-za,'}), TextLine('10.', 'ad-da iri', {'en': 'father of the city'}), TextLine('11.', 'e2 al-la', {'en': '(of) E-Al-la,'}), TextLine('12.', '1(asz@c) ur-esz3-bar', {'en': '1 Ur-eš-bar,'})]), TextArea('column 4', [TextLine('1.', '1(asz@c) iri-zi', {'en': '1 Iri-zi'}), TextLine('2.', '1(asz@c) nin-mu-ba-dah', {'en': '1 Nin-mu-ba-dah'}), TextLine('3.', '1(asz@c) uszur3-du10', {'en': '1 Ušur-du,'}), TextLine('4.', '1(asz@c) sza3-iri-ni-sze3', {'en': '1 Ša-iri-ni-še,'}), TextLine('5.', '1(asz@c) iri-a-nir', {'en': '1 Iri-a-nir,'}), TextLine('6.', 'aszgab', {'en': 'leatherworker,'}), TextLine('7.', '1(asz@c) dingir-ama(LAK769)-mu', {'en': '1 Dingir-ama-mu,'}), TextLine('8.', '1(asz@c) {d}inanna-ukken-a', {'en': '1 Inanna-ukken-a,'}), TextLine('9.', '1(asz@c) gal-an-dab6!-e', {'en': '1 Gal-an-dab-e,'}), TextLine('10.', '1(asz@c) lu2-lul', {'en': '1 Lu-lul,'})]), TextArea('column 5', [TextLine('1.', 'engar', {'en': 'farmer,'}), TextLine('2.', '1(asz@c) amar-szu', {'en': '1 Amar-šu,'}), TextLine('3.', '1(asz@c) ku-li-li', {'en': '1 Ku-li-li,'}), TextLine('4.', 'gudu4', {'en': 'gudu-priest,'}), TextLine('5.', '1(asz@c) dingir-lu2-mah', {'en': '1 Lu-dingir-mah,'}), TextLine('6.', 'engar', {'en': 'farmer:'}), TextLine('7.', 'ki-lu2-inim', {'en': '(they are) the witnesses;'}), TextLine('8.', '1(asz@c) masz2!', {'en': '1 kid (he-goat),'}), TextLine('9.', '2(u@c) ninda', {'en': '20 breads,'}), TextLine('10.', '2(u@c) gug2', {'en': '20 cakes,'}), TextLine('11.', '2(asz@c) kur2 tu7', {'en': '2 kur-measures of soup'}), TextLine('12.', '2(asz@c) kur2 |GA2x(HA.A)|', {'en': '2 kur-measures of dried fish:'})]), TextArea('reverse', []), TextArea('column 1', [TextLine('1.', 'a-har-szi', {'en': '(to) A-har-ši,'}), TextLine('2.', 'dub-sar', {'en': 'the scribe;'}), TextLine('3.', '1(barig@c) sze', {'en': '1 barig-measure of barley,'}), TextLine('4.', '1(asz@c) siki ma-na', {'en': '1 mana of wool,'}), TextLine('5.', '1(asz@c) 1/2(disz@c) kur2 tu7', {'en': '1 and a half kur-measures of soup:'}), TextLine ...

# %% [markdown]
# ## Train and test split

# %%
def train_test_split(pubs):
    r = list(pubs)
    random.shuffle(r)
    n = len(r)
    train = []
    test = []
    for p in r:
        if random.uniform(0, 100) < 10 or p.id in test_publication_ids:
            test.append(p.id)
        else:
            train.append(p.id)
    ntrain = len(train)
    ntest = len(test)
    print(ntrain, "train")
    print(ntest, "test")
    return {"train": sorted(train), "test": sorted(test)}

print("akk")
akk_split = train_test_split(akk_pubs)
print("sux")
sux_split = train_test_split(sux_pubs)
# Out:
# akk
# 870 train
# 108 test
# sux
# 3753 train
# 396 test

# %%
[x for x in akk_split["test"] if x in test_publication_ids]
# Out:
# ['P393923']

# %%
output_obj = { "akk": akk_split, "sux": sux_split }
output_obj.keys()
# Out:
# dict_keys(['akk', 'sux'])

# %%
output_json = json.dumps(output_obj)
output_json[:100]
# Out:
# '{"akk": {"train": ["", "P212432", "P212952", "P215544", "P216437", "P216609", "P216611", "P216615", '

# %%
with open(output_path, "wt") as f:
    f.write(output_json)
